# %% [markdown]
# <a href="https://colab.research.google.com/github/chen-rex0215/115-1/blob/main/9_22py%E4%B8%8A%E8%AA%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
print("2026","09",sep="/")
# Out:
# 2026/09

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=5
h=5
print(id(h))
# Out:
# 10446536

# %%
a=11
b=12
print("{}\n{}".format(a,b))
# Out:
# 11
# 12

# %%
a=11
b=12
print("{e}\n{f}".format(e=a,f=b))
# Out:
# 11
# 12

# %%
a=11.123456
print("{:.2f}".format(a))
# Out:
# 11.12

# %%
a=11.123456
print("{0}".format(a))
print(f"{a}")
# Out:
# 11.123456
# 11.123456

# %%
x=input("請輸入數字")
print(x)
# Out:
# 請輸入數字100
# 100

# %%
x=float(input("請輸入數字"))
print(type(x))
# Out:
# 請輸入數字10.2
# <class 'float'>
