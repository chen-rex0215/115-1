# %% [markdown]
# <a href="https://colab.research.google.com/github/chen-rex0215/115-1/blob/main/411414729_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p=50000
r=0.015
y=5
total=p*((1+r)**y)
print(total)
# Out:
# 53864.20019421873
