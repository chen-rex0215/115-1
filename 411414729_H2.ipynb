# %% [markdown]
# <a href="https://colab.research.google.com/github/chen-rex0215/115-1/blob/main/411414729_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=float(input("請輸入目前金幣數量:"))
y=float(input("請輸入獲得金幣數量:"))
t=x+y
print(f"任務完成！你現在有{t}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成！你現在有750.0枚金幣
